# %%
# !git clone https://github.com/toufiqmusah/brats-generalization.git

# %%
import os
os.environ["HF_TOKEN"] = "..."

# !hf download toufiqmusah/BraTS \
  --repo-type dataset \
  BraTS2025-GLI-PRE-Challenge-TrainingData.zip \
  --local-dir BraTS-Dataset

# !unzip -q BraTS-Dataset/BraTS2025-GLI-PRE-Challenge-TrainingData.zip
# Out:
# BraTS2025-GLI-PRE-Challenge-TrainingData(…): 100%|█| 14.7G/14.7G [00:44<00:00, 3
# ✓ Downloaded
#   path: BraTS-Dataset/BraTS2025-GLI-PRE-Challenge-TrainingData.zip
